# %%
import pandas as pd
import numpy as np

# %%
# 1) Create a series of three different colors
colors = pd.Series(["white", "black", "red"])
colors
# Out:
# 0    white
# 1    black
# 2      red
# dtype: object

# %%
# 2) View the series of different colors
colors.values
# Out:
# array(['white', 'black', 'red'], dtype=object)

# %%
# 3) Create a series of three different car types and view it
cars = pd.Series(["bugatti", "rools royce", "lomborghini"])
cars
# Out:
# 0        bugatti
# 1    rools royce
# 2    lomborghini
# dtype: object

# %%
# 4) Combine the Series of cars and colors into a Data Frame
df = pd.DataFrame({"cars": cars, "colors": colors})
df
# Out:
#           cars colors
# 0      bugatti  white
# 1  rools royce  black
# 2  lomborghini    red

# %%
# 5) Find the different datatypes of the car data Data Frame
df.dtypes
# Out:
# cars      object
# colors    object
# dtype: object

# %%
# 6) Describe your current car sales Data Frame using describe ()
df.describe()
# Out:
#            cars colors
# count         3      3
# unique        3      3
# top     bugatti  white
# freq          1      1

# %%
# 7) Get information about your Data Frame using info ()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cars    3 non-null      object
#  1   colors  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
# 8) Create a Series of different numbers and find the mean of them
numbers = pd.Series([1,2,3,4,5,6,7,8,9])
numbers.mean()
# Out:
# np.float64(5.0)

# %%
# 9) Create a Series of different numbers and find the sum of them
numbers.sum()
# Out:
# np.int64(45)

# %%
# 10) List out all the column names of the car sales Data Frame
df.columns
# Out:
# Index(['cars', 'colors'], dtype='object')

# %%
# 11) Find the length of the car sales Data Frame
len(df)
# Out:
# 3

# %%
# 12) Show the first 5 rows of the car sales Data Frame
df.head()
# Out:
#           cars colors
# 0      bugatti  white
# 1  rools royce  black
# 2  lomborghini    red

# %%
# 13) Show the first 7 rows of the car sales Data Frame
df.head(7)
# Out:
#           cars colors
# 0      bugatti  white
# 1  rools royce  black
# 2  lomborghini    red

# %%
# 14) Show the bottom 5 rows of the car sales Data Frame
df.tail()
# Out:
#           cars colors
# 0      bugatti  white
# 1  rools royce  black
# 2  lomborghini    red

# %%
# 15) Use. loc to select the row at index 0 of the car sales Data Frame
df.loc[0]
# Out:
# cars      bugatti
# colors      white
# Name: 0, dtype: object

# %%
# 16) Use. iloc to select the row at position 0 of the car sales Data Frame
df.iloc[0]
# Out:
# cars      bugatti
# colors      white
# Name: 0, dtype: object

# %%
# 17) Create a crosstab of the Make and Doors columns.
pd.crosstab(df["cars"], df["colors"])
# Out:
# colors       black  red  white
# cars
# bugatti          0    0      1
# lomborghini      0    1      0
# rools royce      1    0      0
